# %%
# Import Libraries
import pandas as pd
import sqlite3
from matplotlib import pyplot as plt
import plotly.graph_objects as go

# %%
# Notebook options
import os

# change working directory
os.chdir('C:\Repos\quant-trading-suite')
print(os.getcwd())
# Out:
# C:\Repos\quant-trading-suite

# %%
# Connect to database
con = sqlite3.connect('data/securities_master.db')
c = con.cursor()

# %%
# Get list of all symbols listed in 2023
query = """SELECT SYMBOL FROM ASSET_INFO
WHERE Launch_Time >= '2023-01-01'
"""
c.execute(query)
symbols = [symbol[0] for symbol in  c.fetchall()]

print(symbols)
# Out:
# ['10000LADYSUSDT', '10000STARLUSDT', '1000BONKUSDT', '1000FLOKIUSDT', '1000PEPEUSDT', 'AGIXUSDT', 'ALPACAUSDT', 'AMBUSDT', 'ARBUSDT', 'ARKMUSDT', 'ARKUSDT', 'ATAUSDT', 'AUCTIONUSDT', 'BADGERUSDT', 'BIGTIMEUSDT', 'BLURUSDT', 'BNTUSDT', 'BNXUSDT', 'BONDUSDT', 'BTC-10NOV23', 'BTC-17NOV23', 'BTC-24NOV23', 'BTC-26JAN24', 'BTC-28JUN24', 'BTC-29DEC23', 'BTC-29MAR24', 'BUSDUSDT', 'CAKEUSDT', 'CFXUSDT', 'COMBOUSDT', 'COREUSDT', 'CYBERUSDT', 'EDUUSDT', 'ETH-10NOV23', 'ETH-17NOV23', 'ETH-24NOV23', 'ETH-26JAN24', 'ETH-28JUN24', 'ETH-29DEC23', 'ETH-29MAR24', 'FETUSDT', 'FLRUSDT', 'FORTHUSDT', 'FRONTUSDT', 'GASUSDT', 'GFTUSDT', 'GLMUSDT', 'GPTUSDT', 'HFTUSDT', 'HIFIUSDT', 'HIGHUSDT', 'HOOKUSDT', 'IDEXUSDT', 'IDUSDT', 'JOEUSDT', 'KASUSDT', 'KEYUSDT', 'LEVERUSDT', 'LOOMUSDT', 'LQTYUSDT', 'MAVUSDT', 'MCUSDT', 'MDTUSDT', 'MEMEUSDT', 'MNTUSDT', 'MULTIUSDT', 'NKNUSDT', 'NMRUSDT', 'NTRNUSDT', 'OGUSDT', 'ORBSUSDT', 'ORDIUSDT', 'OXTUSDT', 'PENDLEUSDT', 'PERPUSDT', 'PHBUSDT', 'POLYXUSDT', 'POWRUSDT', 'PROMUSDT', 'QNTUSDT', 'RADUSDT', 'RDNTUSDT', 'RIFUSDT', 'RLCUSDT', 'RPLUSDT', 'SEIUSDT', 'SNTUSDT', 'SSVUSDT', 'STEEMUSDT', 'STPTUSDT', 'STRAXUSDT', 'SUIUSDT', 'TIAUSDT', 'TOKENUSDT', 'TOMIUSDT', 'TONUSDT', 'TRUUSDT', 'TUSDT', 'UMAUSDT', 'VGXUSDT', 'VRAUSDT', 'WAXPUSDT', 'WLDUSDT', 'WSMUSDT', 'XVGUSDT', 'XVSUSDT', 'YFIIUSDT']

# %%
# Import first 100 bars of each asset


# get column names
query = """
PRAGMA table_info(KLINES_1H)
"""
c.execute(query)
cols = c.fetchall()
col_names = [col[1] for col in cols]

# create dictionary for symbols
data = {}

for symbol in symbols:
    query=f"""SELECT * FROM KLINES_1H WHERE SYMBOL = '{symbol}' LIMIT 100"""
    c.execute(query)
    
    temp = pd.DataFrame(c.fetchall(), columns=col_names)
    
    temp['return'] = temp['Close'].pct_change()

    temp['creturn'] = (1 + temp['return']).cumprod()
    
    data[symbol] = temp

print(symbol)
# Out:
# YFIIUSDT

# %%
data[symbol].head()
# Out:
#   Exchange Product_Type    Symbol                 Time   Open    High     Low  \
# 0    Bybit       linear  YFIIUSDT  2023-08-16 11:00:00  579.7  580.20  574.60
# 1    Bybit       linear  YFIIUSDT  2023-08-16 12:00:00  577.0  577.90  567.30
# 2    Bybit       linear  YFIIUSDT  2023-08-16 13:00:00  572.3  573.85  553.65
# 3    Bybit       linear  YFIIUSDT  2023-08-16 14:00:00  555.8  563.05  551.15
# 4    Bybit       linear  YFIIUSDT  2023-08-16 15:00:00  558.7  558.70  502.90
#
#     Close   Volume            Load_time    return   creturn
# 0  577.00    0.093  2023-11-16 16:11:05       NaN       NaN
# 1  572.30   57.986  2023-11-16 16:11:05 -0.008146  0.991854
# 2  555.80   85.660  2023-11-16 16:11:05 -0.028831  0.963258
# 3  558.70   96.944  2023-11-16 16:11:05  0.005218  0.968284
# 4  513.55  850.543  2023-11-16 16:11:05 -0.080813  0.890035

# %%
data[symbol].tail()
# Out:
#    Exchange Product_Type    Symbol                 Time    Open    High  \
# 95    Bybit       linear  YFIIUSDT  2023-08-20 10:00:00  463.10  468.05
# 96    Bybit       linear  YFIIUSDT  2023-08-20 11:00:00  466.45  468.95
# 97    Bybit       linear  YFIIUSDT  2023-08-20 12:00:00  464.55  469.85
# 98    Bybit       linear  YFIIUSDT  2023-08-20 13:00:00  466.40  467.10
# 99    Bybit       linear  YFIIUSDT  2023-08-20 14:00:00  462.15  463.05
#
#        Low   Close   Volume            Load_time    return   creturn
# 95  462.50  466.45  126.813  2023-11-16 16:11:05  0.007234  0.808406
# 96  463.50  464.55   92.848  2023-11-16 16:11:05 -0.004073  0.805113
# 97  460.85  466.40   97.626  2023-11-16 16:11:05  0.003982  0.808319
# 98  461.80  462.15   12.298  2023-11-16 16:11:05 -0.009112  0.800953
# 99  457.30  458.60   28.085  2023-11-16 16:11:05 -0.007681  0.794801

# %%
# Calculate the cumulative returns for each asset

# %%
# Plot all the cumulative returns one chart

# create a plot
plt.figure(figsize=(10,6))

# plot cumulative returns of each asset
for symbol in symbols:
    temp = data[symbol]
    plt.plot(temp['creturn'], label=symbol, lw=0.8)
  
# set labels and title
plt.xlabel('Time')
plt.ylabel('Cumulative Return')
plt.title('Cumulative Returns for Each DataFrame')

# display the plot without legeng
plt.legend().set_visible(False)

# show the plot
plt.show()

# %%
# Plot all cumulative returns on a plotly graph

# Create a figure
fig = go.Figure()

# Plot cumulative returns for each symbol
for symbol in symbols:
    temp = data[symbol]
    fig.add_trace(go.Scatter(y=temp['creturn'], mode='lines', name=symbol, line=dict(width=0.8)))

# Set layout
fig.update_layout(
    title='Cumulative Returns for Each DataFrame',
    xaxis=dict(title='Time'),
    yaxis=dict(title='Cumulative Return'),
    showlegend=False,  # Hide legend
    width=1000,
    height=600
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="2a54b3a6-ea08-47f5-a9a7-d12bc226a7c4" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a54b3a6-ea08-47f5-a9a7-d12bc226a7c4")) {                    Plotly.newPlot(                        "2a54b3a6-ea08-47f5-a9a7-d12bc226a7c4",                        [{"line":{"width":0.8},"mode":"lines","name":"10000LADYSUSDT","y":[null,0.7956844234659475,0.8472690492245448,0.8634524612272421,0.6463250168577209,0.5799055967633177,0.5883344571813891,0.7828725556304788,0.6968981793661497,0.6240728253540122,0.5721510451786919,0.5758597437626433,0.6254214430209035,0.4780849629130141,0.34356035064059337,0.31523937963587323,0.35603506405933927,0.37997302764666224,0.4875252865812544,0.42886041807147685,0.43189480782198264,0.38435603506405946,0.37255563047875945,0.39345920431557674,0.4787592717464601,0.4157113958192854,0.3941335131490224,0.3894133513149024,0.40222521915037107,0.39244774106540814,0.35940660822656795,0.37255563047875945,0.40289952798381673,0.4123398516520568,0.47606203641267725,0.4672960215778829,0.435940660822657,0.435940660822657,0.44200944032366846,0.4339177343223198,0.4440323668240056,0.4592043155765342,0.5509103169251519,0.5539447066756576,0.524275118004046,0.5579905596763319,0.5991233985165207,0.6048550236008094,0.577208361429535,0.550910316925152,0.5667565745111264,0.6126095751854352,0.5343897505057319,0.5158462575859746,0.5515846257585978,0.5472016183412006,0.5913688469318952,0.5805799055967638,0.5809170600134865,0.603843560350641,0.6284558327714097,0.6142953472690497,0.5815913688469323,0.5974376264329068,0.6159811193526641,0.699932569116656,0.7312879298718818,0.831422791638571,0.7548887390424821,0.759608900876602,0.7741065407956851,0.7299393122049905,0.7134187457855704,0.7255563047875933,0.7592717464598793,0.7633175994605536,0.7545515846257592,0.7326365475387734,0.7420768712070135,0.784221173297371,0.7538772757923137,0.7602832097100479,0.8425488873904255,0.8428860418071485,1.0256237356709383,0.9939312204989895,1.0606877950101155,1.0171948752528666,0.9460552933243431,0.9929197572488206,0.9804450438300748,0.9106540795684429,0.9012137559002029,0.9217801753202973,0.9757248819959548,0.9524612272420775,0.9470667565745118,0.9288604180714775,0.9399865138233318,0.9588671611598119],"type":"scatter"},{"line":{"width":0.8},"mode":"lines","name":"10000STARLUSDT","y":[null,0.959005669428696,0.9622764936764067,1.028347143480157,1.036197121674662,0.9572612298299171,1.0095944177932838,0.9843000436109899,0.9775403401657217,0.9836458787614476,0.9795028347143477,0.9962930658525945,1.0174443959877886,1.0133013519406886,0.9742695159180109,1.0976886175316176,1.0721761883994763,1.0680331443523765,1.0843872655909286,1.0734845180985606,1.080462276493676,1.0920191888355861,1.1286524204099428,1.3554295682511988,1.3680767553423459,1.4095071958133447,1.4535542956825118,1.3711295246402093,1.433711295246402,1.4101613606628869,1.5355429568251195,1.4705625817706058,1.5455734845180982,1.4733972961186217,1.4703445268207587,1.523767989533362,1.543174880069777,1.5337985172263406,1.5078499781945047,1.6668120366332309,1.9090710859136495,1.923244657653728,1.9853903183602262,2.0290013083296983,2.0032708242477097,1.9901875272568683,1.8680767553423456,1.90907108591365,1.9184474487570864,2.0052333187963365,1.9208460532054077,1.9300043610989968,2.0056694286960313,2.221107719145224,2.2562145660706494,2.474487570867858,2.4310946358482335,2.3981683384212817,2.815525512429132,2.858264282599215,2.7945922372437852,2.7158744003488877,2.7300479720889665,1.6833842128216312,1.718927169646751,1.4677278674225904,1.506759703445268,1.5420846053205408,1.5372873964238984,1.5353249018752724,1.516354121238552,1.2876144788486696,1.0874400348887918,1.0695595290013082,1.2110771914522458,1.0732664631487132,1.073920627 ...

# %%
# Calculate the cumulative returns for each asset relative to BTC
